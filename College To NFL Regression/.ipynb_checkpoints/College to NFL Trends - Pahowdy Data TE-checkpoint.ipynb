# %% [markdown]
# ### Old Rough Draft, not updating because QB, WR, RB > TE

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from matplotlib import pyplot as plt

data = pd.read_csv(r'C:\Users\Logan Clark\Documents\Fantasy Stuff\Football Data\pahowdy_cfb_te_training.csv')
rookie_data = pd.read_csv (r'C:\Users\Logan Clark\Documents\Fantasy Stuff\Football Data\pahowdy_cfb_te_rookies.csv', encoding='latin-1')

print(data)
print(rookie_data)
# Out:
#                    Name                cfb_id    pfr_id            School  \
# 0    Albert Okwuegbunam  albert-okwuegbunam-1  OkwuAl00          Missouri
# 1       Harrison Bryant     harrison-bryant-1  BryaHa00  Florida Atlantic
# 2             Cole Kmet           cole-kmet-1  KmetCo00        Notre Dame
# 3          Devin Asiasi        devin-asiasi-1  AsiaDe00              UCLA
# 4        Josiah Deguara      josiah-deguara-1  DeguJo00        Cincinnati
# ..                  ...                   ...       ...               ...
# 300         Mike Roberg         mike-roberg-1  RobeMi00             Idaho
# 301          Shad Meier          shad-meier-1  MeieSh00      Kansas State
# 302        Brian Natkin        brian-natkin-1  NatkBr00     Texas-El Paso
# 303         Billy Baber         billy-baber-1  BabeBi00          Virginia
# 304     Jabari Holloway     jabari-holloway-1  HollJa01        Notre Dame
#
#           Conference  DR   DP  Draft Year  Designation in last Year  \
# 0         SEC (East)   4  118        2020                         2
# 1        CUSA (East)   4  115        2020                         3
# 2                Ind   2   43        2020                         2
# 3     Pac-12 (South)   3   91        2020                         2
# 4    American (East)   3   94        2020                         3
# ..               ...  ..  ...         ...                       ...
# 300         Big West   7  227        2001                         3
# 301   Big 12 (North)   3   90        2001                         3
# 302              WAC  10  300        2001                         3
# 303              ACC   5  141        2001                         3
# 304              Ind   4  119        2001                         3
#
#      Age IN DRAFT YEAR  ...  broadInches  Burst Score    HaSS    WaSS  \
# 0                   22  ...        67.95       112.29  139.15  126.96
# 1                   22  ...       110.00       110.25  106.41   97.09
# 2                   21  ...       123.00       124.40  120.78  107.38
# 3                   23  ...       115.00       109.35  106.77  102.69
# 4                   23  ...       115.00       117.85   98.70   97.52
# ..                 ...  ...          ...          ...     ...     ...
# 300                 23  ...       117.00       117.15  107.39  100.58
# 301                 23  ...       113.00       114.30  101.42   92.53
# 302                 23  ...        98.00        94.90   84.63   83.61
# 303                 22  ...       106.00       109.10  106.07   99.34
# 304                 22  ...       113.00       121.95   88.12   87.06
#
#      # of top 5  finishes  # of top  12 finishes  # of top  24 finishes  \
# 0                       0                      0                      0
# 1                       0                      0                      0
# 2                       0                      0                      0
# 3                       0                      0                      0
# 4                       0                      0                      0
# ..                    ...                    ...                    ...
# 300                     0                      0                      0
# 301                     0                      0                      0
# 302                     0                      0                      0
# 303                     0                      0                      0
# 304                     0                      0                      0
#
#      AVG EP Season 1-3  AVG PPG (PPR) Season 1-3  Score
# 0                 6.63                      7.28  13.91
# 1                 4.60                      4.39   8.99
# 2                 4.91                      4.00   8.91
# 3                 1.24                      1.32   2.56
# 4                 1.45                      1.10   2.55
# ..                 ...                       ...    ...
# 300               3.67                      3.23   6.90
# 301               3.00                      3.16   6.16
# 302               2.25                      3.10   5.35
# 303               2.15                      3.00   5.15
# 304               2.59                      2.56   5.15
#
# [305 rows x 79 columns]
#                  Name               cfb_id    pfr_id            School  \
# 0        Jacob Harris       jacob-harris-2  HarrJa03   Central Florida
# 1           Noah Gray          noah-gray-1  GrayNo00              Duke
# 2       Brevin Jordan      brevin-jordan-1  JordBr00        Miami (FL)
# 3        Kenny Yeboah       kenny-yeboah-1  YeboKe00       Mississippi
# 4        Nick Eubanks       nick-eubanks-1  EubaNi00          Michigan
# 5          Kyle Pitts         kyle-pitts-1  PittKy00           Florida
# 6         Hunter Long        hunter-long-3  LongHu00    Boston College
# 7       Josh Pederson      josh-pederson-1         0  Louisiana-Monroe
# 8       Jake Ferguson      jake-ferguson-1         0         Wisconsin
# 9       Charlie Kolar      charlie-kolar-1         0        Iowa State
# 10    Braden Galloway    braden-galloway-1         0           Clemson
# 11  Peyton Hendershot  peyton-hendershot-1         0           Indiana
# 12      Tommy Tremble      tommy-tremble-1  TremTo00        Notre Dame
# 13     Pat Freiermuth     pat-freiermuth-1  FreiPa00        Penn State
#
#           Conference  DR   DP  Draft Year  Designation in last Year  \
# 0   AmericanÂ (East)   4  141        2021                         3
# 1     ACCÂ (Coastal)  10  300        2021                         3
# 2     ACCÂ (Coastal)   5  147        2021                         2
# 3        SECÂ (West)  10  300        2021                         3
# 4    Big TenÂ (East)  10  300        2021                         3
# 5        SECÂ (East)   1    4        2021                         2
# 6    ACCÂ (Atlantic)   3   81        2021                         2
# 7   Sun BeltÂ (West)  10  300        2021                         3
# 8    Big TenÂ (West)  10  300        2021                         2
# 9             Big 12  10  300        2021                         2
# 10   ACCÂ (Atlantic)  10  300        2021                         2
# 11   Big TenÂ (East)  10  300        2021                         2
# 12   ACCÂ (Atlantic)   3   83        2021                         2
# 13   Big TenÂ (East)   2   55        2021                         2
#
#     Age IN DRAFT YEAR  ...  height   bench     40  3Cone  shuttle  vert  \
# 0                  24  ...    77.0  15.000  4.430   6.51    4.310  40.5
# 1                  22  ...    75.0  15.000  4.620   6.90    4.450  35.0
# 2                  21  ...    75.0  17.000  4.680   7.57    4.500  34.0
# 3                  22  ...    76.0  15.000  9.047   7.16    4.427  34.0
# 4                  24  ...    77.0  19.000  4.690   7.32    4.530  34.0
# 5                  21  ...    78.0  22.000  4.440   7.12    4.350  33.5
# 6                  23  ...    77.0  17.428  4.710   7.41    4.420  32.5
# 7                  23  ...    76.0  19.000  4.810   7.31    4.430  28.5
# 8                  22  ...    76.4  17.428  9.047   7.16    4.427  27.0
# 9                  22  ...    76.4  17.428  9.047   7.16    4.427  27.0
# 10                 21  ...    76.4  17.428  9.047   7.16    4.427  27.0
# 11                 22  ...    76.4  17.428  9.047   7.16    4.427  27.0
# 12                 21  ...    76.4  17.428  9.047   7.16    4.427  31.0
# 13                 22  ...    77.0  17.428  9.047   7.16    4.427  31.0
#
#     broadInches  Burst Score    HaSS    WaSS
# 0           133       135.35  124.61  113.73
# 1           115       117.00  109.54  105.36
# 2           116       115.80  107.07  102.98
# 3           116       115.80  114.00  105.70
# 4           120       117.80  110.99  101.28
# 5           129       121.45  141.80  126.09
# 6           122       116.25  113.13  103.22
# 7           110       103.45   93.34   87.43
# 8           106       117.00  114.00  105.70
# 9           106       117.00  114.00  105.70
# 10          106       117.00  114.00  105.70
# 11          106       117.00  114.00  105.70
# 12          106       117.00  114.00  105.70
# 13          106       117.00  114.00  105.70
#
# [14 rows x 73 columns]

# %%
y = data.iloc[:, 78].to_numpy()

print(len(y))

for i in range(len(y)):
    if y[i] > 20:
        for x in range(5):
            data = data.append(data.iloc[i])
            #npData = np.vstack([npData, npData[i]])
            y = np.append(y, y[i])


print(len(y))
# Out:
# 305
# 465

# %%
plt.hist(y, color = 'blue', edgecolor = 'black',
         bins = 10)
# Out:
# (array([137.,  88.,  35.,  49.,  60.,  48.,  24.,   6.,  12.,   6.]),
#  array([ 0.   ,  5.588, 11.176, 16.764, 22.352, 27.94 , 33.528, 39.116,
#         44.704, 50.292, 55.88 ]),
#  <BarContainer object of 10 artists>)

# %%
cols = list(data.columns)
cols_rookie = list(rookie_data.columns)

names1 = list(rookie_data.iloc[:, 0])

#print(names)

remove = list()
# remove.append(cols[60])
# remove.append(cols[43])
# remove.append(cols[44])
# remove.append(cols[31])
# remove.append(cols[32])
# remove.append(cols[35])
# remove.append(cols[36])
remove_rookie = list()
# remove_rookie.append(cols[60])
# remove_rookie.append(cols[43])
# remove_rookie.append(cols[44])
# remove_rookie.append(cols[31])
# remove_rookie.append(cols[32])
# remove_rookie.append(cols[35])
# remove_rookie.append(cols[36])




for i in range(len(cols)):
    if (i > 72 or i<5):
        remove.append(cols[i])
    
for i in range(len(cols_rookie)):
    if (i<5):
        remove_rookie.append(cols_rookie[i])

print(remove)
print(remove_rookie)
    
x = data.drop(columns=remove)

x_rookie = rookie_data.drop(columns=remove_rookie)

# x = x.drop(columns=['Last.7', 'Best.7'])

# x_rookie = x_rookie.drop(columns=['Last.7', 'Best.7'])

labels = list(x.columns)

labels_rookie = list(x_rookie.columns)
# Out:
# ['Name', 'cfb_id', 'pfr_id', 'School', 'Conference', '# of top 5  finishes', '# of top  12 finishes', '# of top  24 finishes', 'AVG EP Season 1-3', 'AVG PPG (PPR) Season 1-3', 'Score']
# ['Name', 'cfb_id', 'pfr_id', 'School', 'Conference']

# %%
names = ["linReg", "ridgeReg", "lassoReg", "dtReg", "rfReg", "knReg3", "knReg5", "knReg7", "knReg9", "svrReg"]

namesDict = dict()

for i in names:
    namesDict[i] = 0
    
#print(namesDict)

for i in range(100):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

    linReg = LinearRegression().fit(X_train, y_train)
    namesDict["linReg"] = namesDict["linReg"] + linReg.score(X_test, y_test)

    ridgeReg = Ridge().fit(X_train, y_train)
    namesDict["ridgeReg"] = namesDict["ridgeReg"] + ridgeReg.score(X_test, y_test)

    lassoReg = Lasso().fit(X_train, y_train)
    namesDict["lassoReg"] = namesDict["lassoReg"] + lassoReg.score(X_test, y_test)

    dtReg = DecisionTreeRegressor().fit(X_train, y_train)
    namesDict["dtReg"] = namesDict["dtReg"] + dtReg.score(X_test, y_test)

    rfReg = RandomForestRegressor().fit(X_train, y_train)
    namesDict["rfReg"] = namesDict["rfReg"] + rfReg.score(X_test, y_test)

    knReg3 = KNeighborsRegressor(n_neighbors=3).fit(X_train, y_train)
    namesDict["knReg3"] = namesDict["knReg3"] + knReg3.score(X_test, y_test)

    knReg5 = KNeighborsRegressor(n_neighbors=5).fit(X_train, y_train)
    namesDict["knReg5"] = namesDict["knReg5"] + knReg5.score(X_test, y_test)

    knReg7 = KNeighborsRegressor(n_neighbors=7).fit(X_train, y_train)
    namesDict["knReg7"] = namesDict["knReg7"] + knReg7.score(X_test, y_test)

    knReg9 = KNeighborsRegressor(n_neighbors=9).fit(X_train, y_train)
    namesDict["knReg9"] = namesDict["knReg9"] + knReg9.score(X_test, y_test)

    svrReg = SVR().fit(X_train, y_train)
    namesDict["svrReg"] = namesDict["svrReg"] + svrReg.score(X_test, y_test)

for i in namesDict:
    print(i + ": " + str(namesDict[i]/100))
# Out:
# linReg: 0.5169085343549922
# ridgeReg: 0.5469845374508202
# lassoReg: 0.508598872147334
# dtReg: 0.7653473530722902
# rfReg: 0.8665672150473731
# knReg3: 0.7660489560620921
# knReg5: 0.6756345421146962
# knReg7: 0.5933621744250244
# knReg9: 0.5559971126599312
# svrReg: 0.0582858210246426

# %%
importance = lassoReg.coef_
# summarize feature importance
for i,v in enumerate(importance):
    print(labels[i])
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# DR
# Feature: 0, Score: 0.00000
# DP
# Feature: 1, Score: -0.06650
# Draft Year
# Feature: 2, Score: -0.42995
# Designation in last Year
# Feature: 3, Score: -0.00000
# Age IN DRAFT YEAR
# Feature: 4, Score: -0.00000
# Conference Drafted Rate
# Feature: 5, Score: 0.00000
# Conference Hit Rate
# Feature: 6, Score: 0.00000
# Age Draft Hit Rate AVG
# Feature: 7, Score: -0.00000
# Pre Draft  Model
# Feature: 8, Score: 0.45496
# Pre-Draft Percentile
# Feature: 9, Score: 0.00000
# POST Draft Model
# Feature: 10, Score: 0.00000
# Post-Draft Percentile
# Feature: 11, Score: -0.00000
# rec
# Feature: 12, Score: -0.01993
# YARDS
# Feature: 13, Score: -0.00149
# Ypr
# Feature: 14, Score: -0.01690
# G
# Feature: 15, Score: -0.00000
# REC/g
# Feature: 16, Score: 0.00000
# Years Played
# Feature: 17, Score: -0.00000
# College Dominator Rating
# Feature: 18, Score: 0.00000
# YPTpA Dominator
# Feature: 19, Score: 0.00000
# Yards Dominator
# Feature: 20, Score: 0.00000
# Team (Last Year)
# Feature: 21, Score: 0.00000
# conference (Last year)
# Feature: 22, Score: 0.00000
# Hits
# Feature: 23, Score: 0.00000
# First Dominator
# Feature: 24, Score: -0.00000
# Best Dominator
# Feature: 25, Score: 0.00000
# Last Dominator
# Feature: 26, Score: 0.00000
# AVG Dominator
# Feature: 27, Score: 0.00000
# First MS rec Yards
# Feature: 28, Score: -0.00000
# Best MS rec Yards
# Feature: 29, Score: 0.00000
# Last MS rec Yards
# Feature: 30, Score: 0.00000
# AVG MS REC Yds
# Feature: 31, Score: 0.00000
# First PPG
# Feature: 32, Score: 0.15623
# Best PPG
# Feature: 33, Score: 0.00000
# Last PPG
# Feature: 34, Score: 0.60412
# AVG PPG
# Feature: 35, Score: 0.00000
# First RecYds/TmPatt
# Feature: 36, Score: -0.00000
# Best RecYds/TmPatt
# Feature: 37, Score: 0.00000
# Last RecYds/TmPatt
# Feature: 38, Score: 0.00000
# AVG RecYds/TmPatt
# Feature: 39, Score: 0.00000
# First RecYds/TmPatt.1
# Feature: 40, Score: 0.00000
# Best RecYds/TmPatt.1
# Feature: 41, Score: 0.00000
# Last RecYds/TmPatt.1
# Feature: 42, Score: 0.00000
# AVG RecYds/TmPatt.1
# Feature: 43, Score: 0.00000
# First RecYds/TmPatt.2
# Feature: 44, Score: 0.00000
# Best RecYds/TmPatt.2
# Feature: 45, Score: 0.00000
# Last RecYds/TmPatt.2
# Feature: 46, Score: 0.00000
# AVG RecYds/TmPatt.2
# Feature: 47, Score: 0.00000
# YOa (yards Over Average) (RBs=>1top24,Tes>1top12,wrs>1top36))
# Feature: 48, Score: 0.00000
# DOa (Dom Over Average) (>=1 top 24 PPR season by position, drafted 2003-2016)
# Feature: 49, Score: 0.00000
# S/EX (Yds Share Over Expectation using a 5 year conference AVG of top producer)
# Feature: 50, Score: 0.00000
# Production Score (Pos Specific)
# Feature: 51, Score: 0.00000
# PPG Over Conference TE1 AVG (best year)
# Feature: 52, Score: 0.00000
# Compairson to hits
# Feature: 53, Score: 0.00000
# Calvin Scales
# Feature: 54, Score: -0.00000
# Gronk Scales
# Feature: 55, Score: -0.00000
# BMI
# Feature: 56, Score: -0.00000
# weight
# Feature: 57, Score: -0.00000
# height
# Feature: 58, Score: 0.08305
# bench
# Feature: 59, Score: -0.14828
# 40
# Feature: 60, Score: 0.00000
# 3Cone
# Feature: 61, Score: -0.00000
# shuttle
# Feature: 62, Score: -0.00000
# vert
# Feature: 63, Score: -0.18102
# broadInches
# Feature: 64, Score: -0.01610
# Burst Score
# Feature: 65, Score: -0.13674
# HaSS
# Feature: 66, Score: 0.17058
# WaSS
# Feature: 67, Score: 0.11649

# %%
# predictions = list(reg.predict(x_rookie))

# tempDict = dict()

# for i in range(len(predictions)):
#      tempDict[names[i]] = predictions[i]   
        
# new = sorted(tempDict.items(), key=lambda x: x[1], reverse=True)

# for i in new:
#     print(i)

# %%
tempDict = dict()

for i in names1:
    tempDict[i] = 0


for i in range(100):
    realRfReg = RandomForestRegressor().fit(x, y)

    predictions = list(realRfReg.predict(x_rookie))

    for i in range(len(predictions)):
         tempDict[names1[i]] = tempDict[names1[i]] + predictions[i]   

new = sorted(tempDict.items(), key=lambda x: x[1], reverse=True)

for i in new:
    print(i)
# Out:
# ('Kyle Pitts', 2946.628800000001)
# ('Jacob Harris', 2849.7624999999975)
# ('Pat Freiermuth', 1522.512)
# ('Brevin Jordan', 1123.5352999999998)
# ('Hunter Long', 1068.4551999999994)
# ('Jake Ferguson', 820.5251999999999)
# ('Tommy Tremble', 721.7466999999998)
# ('Charlie Kolar', 692.3253999999997)
# ('Josh Pederson', 476.6464000000002)
# ('Noah Gray', 473.38699999999994)
# ('Peyton Hendershot', 473.34550000000036)
# ('Kenny Yeboah', 436.72800000000007)
# ('Braden Galloway', 412.7649000000001)
# ('Nick Eubanks', 256.70470000000006)
